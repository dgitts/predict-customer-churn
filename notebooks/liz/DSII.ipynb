# %%
import pandas as pd
tx_cases_count_csv= pd.read_excel("C:\\Users\\regin\\Desktop\\lale\\datascienceexel\\DSII.xlsx",header=None)
                                    
tx_cases_count_csv.head()
# Out:
#           0                  1             2       3                4   \
# 0  CLIENTNUM     Attrition_Flag  Customer_Age  Gender  Dependent_count
# 1  768805383  Existing Customer            45       M                3
# 2  818770008  Existing Customer            49       F                5
# 3  713982108  Existing Customer            51       M                3
# 4  769911858  Existing Customer            40       F                4
#
#                 5               6                7              8   \
# 0  Education_Level  Marital_Status  Income_Category  Card_Category
# 1      High School         Married      $60K - $80K           Blue
# 2         Graduate          Single   Less than $40K           Blue
# 3         Graduate         Married     $80K - $120K           Blue
# 4      High School         Unknown   Less than $40K           Blue
#
#                9   ...            13                   14               15  \
# ...

# %%
new_header = tx_cases_count_csv.iloc[0] #grab the first row for the header
tx_cases_count_csv = tx_cases_count_csv[1:] #take the data under the header row
tx_cases_count_csv.columns = new_header
tx_cases_count_csv.head()

#counties=(tx_cases_count_csv['County Name'])


#df = pd.DataFrame (counties,columns=['County_Name'])
#df.County_Name=counties
#df.drop(df.tail(1).index,inplace=True) # drop last n rows
#df
# Out:
# 0  CLIENTNUM     Attrition_Flag Customer_Age Gender Dependent_count  \
# 1  768805383  Existing Customer           45      M               3
# 2  818770008  Existing Customer           49      F               5
# 3  713982108  Existing Customer           51      M               3
# 4  769911858  Existing Customer           40      F               4
# 5  709106358  Existing Customer           40      M               3
#
# 0 Education_Level Marital_Status Income_Category Card_Category Months_on_book  \
# 1     High School        Married     $60K - $80K          Blue             39
# 2        Graduate         Single  Less than $40K          Blue             44
# 3        Graduate        Married    $80K - $120K          Blue             36
# 4     High School        Unknown  Less than $40K          Blue             34
# 5      Uneducated        Married     $60K - $80K          Blue             21
#
# 0  ... Credit_Limit Total_Revolving_Bal Avg_Open_To_Buy Total_Amt_Chng_Q4_Q1  \
# ...

# %%
df=tx_cases_count_csv.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1'], axis=1)
df.head()
# Out:
# 0  CLIENTNUM     Attrition_Flag Customer_Age Gender Dependent_count  \
# 1  768805383  Existing Customer           45      M               3
# 2  818770008  Existing Customer           49      F               5
# 3  713982108  Existing Customer           51      M               3
# 4  769911858  Existing Customer           40      F               4
# 5  709106358  Existing Customer           40      M               3
#
# 0 Education_Level Marital_Status Income_Category Card_Category Months_on_book  \
# 1     High School        Married     $60K - $80K          Blue             39
# 2        Graduate         Single  Less than $40K          Blue             44
# 3        Graduate        Married    $80K - $120K          Blue             36
# 4     High School        Unknown  Less than $40K          Blue             34
# 5      Uneducated        Married     $60K - $80K          Blue             21
#
# 0  ... Months_Inactive_12_mon Contacts_Count_12_mon Credit_Limit  \
# ...

# %% [markdown]
# Attrited customers refer to those that ended their relationship with the company. for one reasn or another.
# to find the numberof attrited customers we count how many are in the column.

# %%
df.Attrition_Flag.unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
1627/8500*100
# Out:
# 19.141176470588235

# %% [markdown]
# once we find the percentage of attrited customers it is importantto know what income and card category they are on.

# %%
piechrt=df.groupby('Attrition_Flag').nunique()
# Out:
# 0                  CLIENTNUM  Attrition_Flag  Customer_Age  Gender  \
# Attrition_Flag
# Attrited Customer       1627               1            42       2
# Existing Customer       8500               1            45       2
#
# 0                  Dependent_count  Education_Level  Marital_Status  \
# Attrition_Flag
# Attrited Customer                6                7               4
# Existing Customer                6                7               4
#
# 0                  Income_Category  Card_Category  Months_on_book  ...  \
# Attrition_Flag                                                     ...
# Attrited Customer                6              4              44  ...
# Existing Customer                6              4              44  ...
#
# 0                  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# Attrition_Flag
# Attrited Customer                       7                      7
# Existing Customer                       7                      6
#
# ...

# %%
import plotly.express as px
# This dataframe has 244 lines, but 4 distinct values for `day`
df = df
fig = px.pie(df, values='CLIENTNUM', names='Attrition_Flag')
fig.show()
# Out:
# <div>
#
#
#             <div id="bb5da5af-be92-4202-b39e-e092e283642f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb5da5af-be92-4202-b39e-e092e283642f")) {
#                     Plotly.newPlot(
#                         'bb5da5af-be92-4202-b39e-e092e283642f',
# ...

# %% [markdown]
# Find out how many card categories there are:

# %%
df.Card_Category.unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  password="yourpassword"
)

print(mydb)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-57-2bd59aef0659> in <module>
# ----> 1 import mysql.connector
#       2
#       3 mydb = mysql.connector.connect(
#       4   host="localhost",
#       5   user="yourusername",
#
# ModuleNotFoundError: No module named 'mysql'

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  password="yourpassword",
  database="mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-5d5bae9ee625> in <module>
# ----> 1 import mysql.connector
#       2
#       3 mydb = mysql.connector.connect(
#       4   host="localhost",
#       5   user="yourusername",
#
# ModuleNotFoundError: No module named 'mysql'

# %%
select Card_Category in df 
where Attrition_Flag= 'Attrited Customer'
